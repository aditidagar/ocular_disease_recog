# %% [markdown]
# <a href="https://colab.research.google.com/github/aditidagar/ocular_disease_recog/blob/Adding-VGG16-model-Jupiter-files/MODEL/VGG16_full_model_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/amd/')
isConcat = False
# Out:
# Mounted at /amd/

# %% [markdown]
# Note:
# * edit the path to the dataset depending wehere it was saved. Aslo vgg16_weights_tf_dim_ordering_tf_kernels.h5 is avalible in the repo or you could download it by yourself.
#
# *  vgg16_weights_tf_dim_ordering_tf_kernels.h5 should be used if it is impossible to get the weights in defining the keras.VGG16 model or for manually defined model.

# %%
if isConcat:
    # !cp /amd/My\ Drive/CSC490Data/ODIR-5K_aug_contrast_concat.zip /content/
    # !unzip ODIR-5K_aug_contrast_concat.zip
else:
    # !cp /amd/My\ Drive/CSC490Data/ODIR-5K_aug_contrast_NOFUSION.zip /content/
    # !unzip ODIR-5K_aug_contrast_NOFUSION.zip 
    # !cp /amd/My\ Drive/CSC490Data/ODIR-5K_aug_contrast_SUM.zip /content/
    # !unzip ODIR-5K_aug_contrast_SUM.zip

# %% [markdown]
# Most of the preparation work is taken from the Grzegors model.
#
# Grzegorz model  https://github.com/GrzegorzMeller/AlgorithmsForMassiveData

# %%
import tensorflow as tf
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt
import IPython.display as display
import numpy as np
import glob
import random

BATCH_SIZE = 32
IMG_WIDTH = 250
if isConcat:
    IMG_WIDTH = 500
IMG_HEIGHT= 250
CLASS_NAMES = ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']

# %%
tf.random.set_seed(10) 
resampled1_ds =  tf.data.Dataset.list_files("ODIR-5K/Training Images/*.jpg")
test_ds = tf.data.Dataset.list_files("ODIR-5K/Validation_Images/*.jpg")

# %%
def get_label(name):
  parts = tf.strings.split(name, sep="-")
  label = tf.strings.split(parts[-1], sep=".")
  label = tf.strings.bytes_split(label[0])
  l = [0, 0, 0, 0, 0, 0, 0, 0]

  for e in label:
    if e != '&' and e != 'X':
      if e == 'N':
        l[0] = 1
      elif e == 'D':
        l[1] = 1
      elif e == 'G':
        l[2] = 1
      elif e == 'C':
        l[3] = 1
      elif e == 'A':
        l[4] = 1
      elif e == 'H':
        l[5] = 1
      elif e == 'M':
        l[6] = 1
      elif e == 'O':
        l[7] = 1

  return l

def get_name(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  return parts[-1]

def decode_img(img):
  img = tf.image.decode_jpeg(img, channels=3)
  #img = tf.image.adjust_contrast(img, 2)
  img = tf.image.convert_image_dtype(img, tf.float32)
  #img = tf.image.resize_with_pad(img, IMG_HEIGHT, IMG_WIDTH, method='bilinear', antialias=False)
  return img

def process_path(file_path):
  name = get_name(file_path)
  label = get_label(name)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
AUTOTUNE = tf.data.experimental.AUTOTUNE
resampled_named_ds = resampled1_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_named_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
#  Might need to 
for image, label in resampled_named_ds.take(6):
  print(image.shape)
  plt.imshow(image.numpy())
  print('label: ', CLASS_NAMES[np.nonzero(label.numpy()==1)[0][0]], label.numpy())
# Out:
# (250, 250, 3)
# label:  G [0 0 1 0 0 0 0 0]
# (250, 250, 3)
# label:  C [0 0 0 1 0 0 0 0]
# (250, 250, 3)
# label:  A [0 0 0 0 1 0 0 0]
# (250, 250, 3)
# label:  N [1 0 0 0 0 0 0 0]
# (250, 250, 3)
# label:  A [0 0 0 0 1 0 0 0]
# (250, 250, 3)
# label:  D [0 1 0 0 0 0 0 0]

# %%
def randomly_augment(image,label):
  image = tf.image.random_flip_left_right(image)
  #image = tf.image.central_crop(image, central_fraction=0.9)
  #image = tf.image.resize_with_pad(image, IMG_HEIGHT, IMG_WIDTH, method='bilinear', antialias=False)
  return image, label

def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  #ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size, reshuffle_each_iteration=False)
  #ds = ds.map(randomly_augment, num_parallel_calls=AUTOTUNE)
  ds = ds.repeat()
  ds = ds.batch(BATCH_SIZE, drop_remainder=True)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  ds = ds.cache()
  ds = ds.batch(32, drop_remainder=True) #all elemetnts for training should be batched in one!
  ds = ds.repeat()

  return ds

# %%
final_train_ds = prepare_for_training(resampled_named_ds,cache=True,shuffle_buffer_size=1000)
final_test_ds = prepare_for_testing(test_named_ds,cache=True,shuffle_buffer_size=100)

# %%
for example in final_train_ds.take(1):
  image, label = example
  break
im, lab = image[13], label[13]
plt.imshow(im.numpy())
print(lab.numpy())
# Out:
# [0 1 0 0 0 0 0 0]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
tf.random.set_seed(10) 
vgg = VGG16(weights="imagenet",include_top = False,input_shape=(IMG_HEIGHT,IMG_WIDTH,3))

# Uncoment this if you do not want to train all of the layers
# for layer in vgg.layers:
#     layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(8,activation="sigmoid"))

checkpoint = ModelCheckpoint("VGG16_our_weights_no_img_aug.h5",monitor="val_accuracy",verbose=1, save_best_only=True, save_weights_only=False, period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
#  TODO : test with different optimizers such as SGD and Adam with different alphas

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True),loss="binary_crossentropy", metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 8)                 200712
#
# =================================================================
# Total params: 14,915,400
# Trainable params: 14,915,400
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(final_train_ds,
                    steps_per_epoch = 450, # todo update this varialbe since there is more data and it requires more steps which is # data / (batch size = 32)
                    epochs=50,
                    validation_data=final_test_ds,
                    validation_steps = 60, # might need to increase this 
                    verbose=1,
                    callbacks=[checkpoint]
                    )
# Out:
# Epoch 1/50
# 450/450 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.5299 - precision: 0.7514 - recall: 0.3160
# Epoch 00001: val_accuracy improved from -inf to 0.49844, saving model to VGG16_our_weights_no_img_aug.h5
# 450/450 [==============================] - 149s 280ms/step - loss: 0.2659 - accuracy: 0.5299 - precision: 0.7514 - recall: 0.3160 - val_loss: 0.2926 - val_accuracy: 0.4984 - val_precision: 0.5887 - val_recall: 0.2675
# Epoch 2/50
# 450/450 [==============================] - ETA: 0s - loss: 0.1855 - accuracy: 0.6984 - precision: 0.7867 - recall: 0.5585
# Epoch 00002: val_accuracy did not improve from 0.49844
# 450/450 [==============================] - 125s 279ms/step - loss: 0.1855 - accuracy: 0.6984 - precision: 0.7867 - recall: 0.5585 - val_loss: 0.3137 - val_accuracy: 0.4490 - val_precision: 0.5318 - val_recall: 0.2688
# Epoch 3/50
# 450/450 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.7499 - precision: 0.8104 - recall: 0.6417
# Epoch 00003: val_accuracy did not improve from 0.49844
# 450/450 [==============================] - 125s 278ms/step - loss: 0.1581 - accuracy: 0.7499 - precision: 0.8104 - recall: 0.6417 - val_loss: 0.2988 - val_accuracy: 0.4833 - val_precision: 0.5830 - val_recall: 0.2907
# Epoch 4/50
# 450/450 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.7911 - precision: 0.8335 - recall: 0.6964
# Epoch 00004: val_accuracy improved from 0.49844 to 0.51094, saving model to VGG16_our_weights_no_img_aug.h5
# 450/450 [==============================] - 126s 279ms/step - loss: 0.1369 - accuracy: 0.7911 - precision: 0.8335 - recall: 0.6964 - val_loss: 0.2974 - val_accuracy: 0.5109 - val_precision: 0.5769 - val_recall: 0.4071
# Epoch 5/50
# 450/450 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.8220 - precision: 0.8502 - recall: 0.7439
# Epoch 00005: val_accuracy did not improve from 0.51094
# 450/450 [==============================] - 125s 278ms/step - loss: 0.1202 - accuracy: 0.8220 - precision: 0.8502 - recall: 0.7439 - val_loss: 0.3027 - val_accuracy: 0.4880 - val_precision: 0.5793 - val_recall: 0.3965
# Epoch 6/50
# 450/450 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.8351 - precision: 0.8619 - recall: 0.7684
# Epoch 00006: val_accuracy did not improve from 0.51094
# 450/450 [==============================] - 125s 278ms/step - loss: 0.1088 - accuracy: 0.8351 - precision: 0.8619 - recall: 0.7684 - val_loss: 0.3096 - val_accuracy: 0.4885 - val_precision: 0.5370 - val_recall: 0.4609
# Epoch 7/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.8558 - precision: 0.8764 - recall: 0.7951
# Epoch 00007: val_accuracy did not improve from 0.51094
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0989 - accuracy: 0.8558 - precision: 0.8764 - recall: 0.7951 - val_loss: 0.3214 - val_accuracy: 0.4667 - val_precision: 0.5357 - val_recall: 0.4042
# Epoch 8/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.8771 - precision: 0.8918 - recall: 0.8267
# Epoch 00008: val_accuracy improved from 0.51094 to 0.54271, saving model to VGG16_our_weights_no_img_aug.h5
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0866 - accuracy: 0.8771 - precision: 0.8918 - recall: 0.8267 - val_loss: 0.3308 - val_accuracy: 0.5427 - val_precision: 0.5862 - val_recall: 0.4708
# Epoch 9/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.8909 - precision: 0.9031 - recall: 0.8494
# Epoch 00009: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0763 - accuracy: 0.8909 - precision: 0.9031 - recall: 0.8494 - val_loss: 0.3410 - val_accuracy: 0.5047 - val_precision: 0.6031 - val_recall: 0.3738
# Epoch 10/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9079 - precision: 0.9175 - recall: 0.8744
# Epoch 00010: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0674 - accuracy: 0.9079 - precision: 0.9175 - recall: 0.8744 - val_loss: 0.3643 - val_accuracy: 0.5172 - val_precision: 0.5732 - val_recall: 0.4536
# Epoch 11/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9207 - precision: 0.9274 - recall: 0.8926
# Epoch 00011: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0580 - accuracy: 0.9207 - precision: 0.9274 - recall: 0.8926 - val_loss: 0.3959 - val_accuracy: 0.4786 - val_precision: 0.5566 - val_recall: 0.3910
# Epoch 12/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9317 - precision: 0.9379 - recall: 0.9117
# Epoch 00012: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0508 - accuracy: 0.9317 - precision: 0.9379 - recall: 0.9117 - val_loss: 0.3940 - val_accuracy: 0.5130 - val_precision: 0.5517 - val_recall: 0.4931
# Epoch 13/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9436 - precision: 0.9490 - recall: 0.9266
# Epoch 00013: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0416 - accuracy: 0.9436 - precision: 0.9490 - recall: 0.9266 - val_loss: 0.4572 - val_accuracy: 0.5063 - val_precision: 0.5276 - val_recall: 0.4919
# Epoch 14/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9551 - precision: 0.9569 - recall: 0.9389
# Epoch 00014: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0352 - accuracy: 0.9551 - precision: 0.9569 - recall: 0.9389 - val_loss: 0.4502 - val_accuracy: 0.4698 - val_precision: 0.5299 - val_recall: 0.4203
# Epoch 15/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9583 - precision: 0.9641 - recall: 0.9510
# Epoch 00015: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0301 - accuracy: 0.9583 - precision: 0.9641 - recall: 0.9510 - val_loss: 0.4333 - val_accuracy: 0.5250 - val_precision: 0.5580 - val_recall: 0.4975
# Epoch 16/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9676 - precision: 0.9756 - recall: 0.9693
# Epoch 00016: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0212 - accuracy: 0.9676 - precision: 0.9756 - recall: 0.9693 - val_loss: 0.5482 - val_accuracy: 0.5021 - val_precision: 0.5949 - val_recall: 0.3831
# Epoch 17/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9683 - precision: 0.9769 - recall: 0.9682
# Epoch 00017: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0204 - accuracy: 0.9683 - precision: 0.9769 - recall: 0.9682 - val_loss: 0.5297 - val_accuracy: 0.4911 - val_precision: 0.5132 - val_recall: 0.4908
# Epoch 18/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9724 - precision: 0.9847 - recall: 0.9804
# Epoch 00018: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0147 - accuracy: 0.9724 - precision: 0.9847 - recall: 0.9804 - val_loss: 0.5364 - val_accuracy: 0.5057 - val_precision: 0.5372 - val_recall: 0.4653
# Epoch 19/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9731 - precision: 0.9856 - recall: 0.9799
# Epoch 00019: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0137 - accuracy: 0.9731 - precision: 0.9856 - recall: 0.9799 - val_loss: 0.6550 - val_accuracy: 0.4865 - val_precision: 0.5402 - val_recall: 0.4480
# Epoch 20/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9749 - precision: 0.9889 - recall: 0.9881
# Epoch 00020: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0101 - accuracy: 0.9749 - precision: 0.9889 - recall: 0.9881 - val_loss: 0.6022 - val_accuracy: 0.5229 - val_precision: 0.5848 - val_recall: 0.4616
# Epoch 21/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9769 - precision: 0.9901 - recall: 0.9872
# Epoch 00021: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0096 - accuracy: 0.9769 - precision: 0.9901 - recall: 0.9872 - val_loss: 0.6451 - val_accuracy: 0.5115 - val_precision: 0.5486 - val_recall: 0.4860
# Epoch 22/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9776 - precision: 0.9928 - recall: 0.9903
# Epoch 00022: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0078 - accuracy: 0.9776 - precision: 0.9928 - recall: 0.9903 - val_loss: 0.7056 - val_accuracy: 0.5083 - val_precision: 0.5565 - val_recall: 0.4700
# Epoch 23/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9778 - precision: 0.9951 - recall: 0.9947
# Epoch 00023: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0051 - accuracy: 0.9778 - precision: 0.9951 - recall: 0.9947 - val_loss: 0.7202 - val_accuracy: 0.5193 - val_precision: 0.5903 - val_recall: 0.4303
# Epoch 24/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9764 - precision: 0.9931 - recall: 0.9911
# Epoch 00024: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 277ms/step - loss: 0.0069 - accuracy: 0.9764 - precision: 0.9931 - recall: 0.9911 - val_loss: 0.7212 - val_accuracy: 0.4807 - val_precision: 0.5612 - val_recall: 0.3989
# Epoch 25/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9787 - precision: 0.9963 - recall: 0.9954
# Epoch 00025: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0043 - accuracy: 0.9787 - precision: 0.9963 - recall: 0.9954 - val_loss: 0.7102 - val_accuracy: 0.5068 - val_precision: 0.5511 - val_recall: 0.4639
# Epoch 26/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9776 - precision: 0.9978 - recall: 0.9975
# Epoch 00026: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0028 - accuracy: 0.9776 - precision: 0.9978 - recall: 0.9975 - val_loss: 0.7763 - val_accuracy: 0.5318 - val_precision: 0.5915 - val_recall: 0.4549
# Epoch 27/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9788 - precision: 0.9995 - recall: 0.9993
# Epoch 00027: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0010 - accuracy: 0.9788 - precision: 0.9995 - recall: 0.9993 - val_loss: 0.8702 - val_accuracy: 0.5229 - val_precision: 0.5816 - val_recall: 0.4540
# Epoch 28/50
# 450/450 [==============================] - ETA: 0s - loss: 4.2702e-04 - accuracy: 0.9799 - precision: 0.9998 - recall: 0.9999
# Epoch 00028: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 4.2702e-04 - accuracy: 0.9799 - precision: 0.9998 - recall: 0.9999 - val_loss: 0.9166 - val_accuracy: 0.5281 - val_precision: 0.5857 - val_recall: 0.4687
# Epoch 29/50
# 450/450 [==============================] - ETA: 0s - loss: 1.5484e-04 - accuracy: 0.9776 - precision: 0.9999 - recall: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 1.5484e-04 - accuracy: 0.9776 - precision: 0.9999 - recall: 1.0000 - val_loss: 0.9068 - val_accuracy: 0.5229 - val_precision: 0.5777 - val_recall: 0.4645
# Epoch 30/50
# 450/450 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9781 - precision: 0.9968 - recall: 0.9967
# Epoch 00030: val_accuracy did not improve from 0.54271
# 450/450 [==============================] - 125s 278ms/step - loss: 0.0029 - accuracy: 0.9781 - precision: 0.9968 - recall: 0.9967 - val_loss: 0.7797 - val_accuracy: 0.5375 - val_precision: 0.5744 - val_recall: 0.5228
# Epoch 31/50
# 123/450 [=======>......................] - ETA: 1:25 - loss: 0.0029 - accuracy: 0.9759 - precision: 0.9978 - recall: 0.9966
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-531fdef6ee07> in <module>()
#       5                     validation_steps = 60, # might need to increase this
#       6                     verbose=1,
# ----> 7                     callbacks=[checkpoint]
#       8                     )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
# !cp /content/VGG16_our_weights_no_img_aug.h5 /amd/My\ Drive/CSC490Data/  # change you your path

# %%
model.load_weights('VGG16_our_weights_no_img_aug.h5')
model.evaluate(final_test_ds, steps=100)
# Out:
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3302 - accuracy: 0.5406 - precision: 0.5832 - recall: 0.4674
# [0.330173134803772,
#  0.5406249761581421,
#  0.5832474827766418,
#  0.46740028262138367]

# %%
#  Grzegorz model  https://github.com/GrzegorzMeller/AlgorithmsForMassiveData

model_cnn = tf.keras.Sequential([
    
    # 1st VGG block
    tf.keras.layers.Conv2D(32, (5, 5), padding = "same", input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation("relu"),

    tf.keras.layers.Conv2D(32, (5, 5), padding = "same"),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation("relu"),

    tf.keras.layers.MaxPooling2D(pool_size = (3, 3)),
    tf.keras.layers.Dropout(0.45),

    #2nd VGG block
    tf.keras.layers.Conv2D(128, (5, 5), padding = "same"),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation("relu"),

    tf.keras.layers.Conv2D(128, (5, 5), padding = "same"),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation("relu"),

    tf.keras.layers.MaxPooling2D(pool_size = (3, 3)),
    tf.keras.layers.Dropout(0.45),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(8, activation = 'sigmoid')
])

model_cnn.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 250, 250, 32)      2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 250, 250, 32)      96
# _________________________________________________________________
# activation (Activation)      (None, 250, 250, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 250, 250, 32)      25632
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 250, 250, 32)      96
# _________________________________________________________________
# activation_1 (Activation)    (None, 250, 250, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 83, 83, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 83, 83, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 83, 83, 128)       102528
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 83, 83, 128)       384
# _________________________________________________________________
# activation_2 (Activation)    (None, 83, 83, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 83, 83, 128)       409728
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 83, 83, 128)       384
# _________________________________________________________________
# activation_3 (Activation)    (None, 83, 83, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 27, 27, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27, 27, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 93312)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 746504
# =================================================================
# Total params: 1,287,784
# Trainable params: 1,287,144
# Non-trainable params: 640
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
#  This is full VGG 16 model
tf.random.set_seed(7) 
model_cnn_deep_jordi = tf.keras.Sequential()
# 1st VGG block
layer = tf.keras.layers.Conv2D(64, (3, 3), padding = "same", input_shape=(IMG_HEIGHT, IMG_WIDTH ,3),activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(64, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
layer.trainable = False
model_cnn_deep_jordi.add(layer)


#2nd VGG bloc
layer = tf.keras.layers.Conv2D(128, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(128, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
layer.trainable = False
model_cnn_deep_jordi.add(layer)


#3nd VGG bloc
layer = tf.keras.layers.Conv2D(256, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(256, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(256, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
layer.trainable = False
model_cnn_deep_jordi.add(layer)


#4nd VGG bloc
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
layer.trainable = False
model_cnn_deep_jordi.add(layer)


#5nd VGG bloc
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Conv2D(512, (3, 3), padding = "same", activation="relu")
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
layer.trainable = False
model_cnn_deep_jordi.add(layer)


layer = tf.keras.layers.Flatten()
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Dense(4096, activation='relu')
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Dense(4096, activation='relu')
layer.trainable = False
model_cnn_deep_jordi.add(layer)
layer = tf.keras.layers.Dense(1000, activation='softmax')
layer.trainable = False
model_cnn_deep_jordi.add(layer)

model_cnn_deep_jordi.load_weights("vgg16_weights_tf_dim_ordering_tf_kernels.h5")
model_cnn_deep_jordi.add(tf.keras.layers.Flatten()) # softmax or sigmoid
model_cnn_deep_jordi.add(tf.keras.layers.Dense(8, activation = 'sigmoid')) # softmax or sigmoid
# categorical_crossentropy  or binary_crossentropy
model_cnn_deep_jordi.compile(optimizer=tf.keras.optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True), # Adam(learning_rate=0.0001)
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

model_cnn_deep_jordi.summary()

# %%
#  dont run the Grzegorz model, because it takes too long to train and does not provide reliable resluts with just 2 VGG blocks
# history_cnn = model_cnn.fit(final_train_ds.repeat(),
#                     #batch_size=32,
#                     epochs=50,
#                     steps_per_epoch = 450, #train_elements/batch_size
#                     validation_data=final_test_ds.repeat(),
#                     validation_steps = 60,
#                     use_multiprocessing=True,
#                     #class_weight=class_weight
#                     )
# Out:
# Epoch 1/50

# %% [markdown]
# TODO: clean this up
#
# # Clean up:

# %%
# !zip -r mdl.zip mdl/
# Out:
#   adding: mdl/ (stored 0%)
#   adding: mdl/saved_model.pb (deflated 91%)
#   adding: mdl/assets/ (stored 0%)
#   adding: mdl/variables/ (stored 0%)
#   adding: mdl/variables/variables.index (deflated 71%)
#   adding: mdl/variables/variables.data-00000-of-00002 (deflated 81%)
#   adding: mdl/variables/variables.data-00001-of-00002 (deflated 8%)

# %%
# !cp -r mdl.zip /amd/My\ Drive

# %%
# !rm -rf ODIR-5K/

# %%
# !rm -f ODIR-5K_aug.zip
